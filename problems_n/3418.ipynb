# %%
import numpy as np
from typing import List

# %%
class Solution:

    def maximum_amount(self, coins: List[List[int]]) -> int:
        ...

# %%
coins1 = [[1, 3, 4], [5, 6, 9]]
print(np.matrix(coins1))
# Out:
# [[1 3 4]
#  [5 6 9]]
